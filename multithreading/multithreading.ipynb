# %% [markdown]
# <center><img src="https://synapsedatascience.com.br/wp-content/uploads/2020/12/logo-jupyter.png" width="300"/></center>

# %% [markdown]
# https://towardsdatascience.com/10x-faster-parallel-python-without-python-multiprocessing-e5017c93cce1

# %% [markdown]
# 1. Pensar em um caso de uso
# 2. Testar o Ray tbm

# %% [markdown]
# # Introdução
#
# Essa materia é muito boa ---> https://www.machinelearningplus.com/python/parallel-processing-python/

# %% [markdown]
# # Motivação

# %% [markdown]
# # Multiprocessamento
#
# 3. What is Synchronous and Asynchronous execution?

# %%
# importar biblioteca de multiprocessamento
import multiprocessing

# %%
# obter o número de threads máximo do seu processador
NUM_THREADS = multiprocessing.cpu_count()

print("Quantidade de threads:", NUM_THREADS)
# Out:
# Quantidade de threads: 24

# %%
# criar um pool de processamento
pool = multiprocessing.Pool(NUM_THREADS)

# %%
try:
    args = [(all_ais_events, split_test_day, num_days,
            pipeline_validation_learn, 
            incremental_learn, test_learn, outside_events, 
            False, False, output_dir, check_trained)
            for num_days in num_days_vec
            for incremental_learn in incremental_learn_vec]

    pool.starmap_async(model.hotspot_pipeline_train, args)

finally:
    pool.close()
    pool.join()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ad22a5e8437e> in <module>
# ----> 1 fibonacci(100)
#
# <ipython-input-8-01df10fae4df> in fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-8-01df10fae4df> in fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-8-01df10fae4df> in fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-8-01df10fae4df> in fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-8-01df10fae4df> in fibonacci(n)
#       3         return n
#       4     else:
# ...
